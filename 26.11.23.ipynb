# %%
# !pip install pandas

# %%
import pandas as pd

# %%
data=[{
    'name':"arul",
    'age':24,
    'email':'arul@gmail.com'
},{
    'name':"ebi",
    'age':25,
    'email':'ebi@gmail.com'
}
     ]
ans=pd.DataFrame(data)
ans
# Out:
#    name  age           email
# 0  arul   24  arul@gmail.com
# 1   ebi   25   ebi@gmail.com

# %%
# Create a dataframe which comprise of  name,email,course of the candidate have 5 students

students=[]
for index in range(5):
    student={
        'name':input("Name:"),
        'email':input("Email"),
        'course':input("Course")
    }
    students.append(student)
df=pd.DataFrame(students)
df
# Out:
# Name: pandi
# Email pandidurai9009@gmail.com
# Course AI and Ml
# Name: Augstin
# Email augstin@gmail.com
# Course frontend developer
# Name: aruna
# Email aruna@gmail.com
# Course data Analyst
# Name: thivilan
# Email thivilan@gmail.com
# Course doctor
# Name: thivies
# Email thivies@gmail.com
# Course doctor
#        name                     email              course
# 0     pandi  pandidurai9009@gmail.com           AI and Ml
# 1   Augstin         augstin@gmail.com  frontend developer
# 2     aruna           aruna@gmail.com        data Analyst
# 3  thivilan        thivilan@gmail.com              doctor
# 4   thivies         thivies@gmail.com              doctor

# %%
df=pd.DataFrame()
df['name']=['a','b','c','d']
df['emai']=['a@gmail.com','b@gmail.com','c@gmail.com','d@gmail.com']
df['course']=['DS','DS','DE','DE']
df['Fee']=[10,20,30,40]
df['age']=[21,24,23,21]
df
# Out:
#   name         emai course  Fee  age
# 0    a  a@gmail.com     DS   10   21
# 1    b  b@gmail.com     DS   20   24
# 2    c  c@gmail.com     DE   30   23
# 3    d  d@gmail.com     DE   40   21

# %%
import pandas as pd
df=pd.read_csv("C:/Users/User/Downloads/ds_salaries.csv")
df
# Out:
#      Unnamed: 0  work_year experience_level employment_type  \
# 0             0       2020               MI              FT
# 1             1       2020               SE              FT
# 2             2       2020               SE              FT
# 3             3       2020               MI              FT
# 4             4       2020               SE              FT
# ..          ...        ...              ...             ...
# 602         602       2022               SE              FT
# 603         603       2022               SE              FT
# 604         604       2022               SE              FT
# 605         605       2022               SE              FT
# 606         606       2022               MI              FT
#
#                       job_title  salary salary_currency  salary_in_usd  \
# 0                Data Scientist   70000             EUR          79833
# 1    Machine Learning Scientist  260000             USD         260000
# ...

# %%
import pandas as pd
df=pd.read_excel(r"C:/Users/User/Downloads/IndStartUpFunding.xlsx")
df
# Out:
#       Sr No      Date dd/mm/yyyy                  Startup Name  \
# 0         1  2020-01-09 00:00:00                        BYJU’S
# 1         2  2020-01-13 00:00:00                        Shuttl
# 2         3  2020-01-09 00:00:00                     Mamaearth
# 3         4  2020-01-02 00:00:00  https://www.wealthbucket.in/
# 4         5  2020-01-02 00:00:00                        Fashor
# ...     ...                  ...                           ...
# 3039   3040  2015-01-29 00:00:00                    Printvenue
# 3040   3041  2015-01-29 00:00:00                      Graphene
# 3041   3042  2015-01-30 00:00:00                Mad Street Den
# 3042   3043  2015-01-30 00:00:00                     Simplotel
# 3043   3044  2015-01-31 00:00:00              couponmachine.in
#
#         Industry Vertical                            SubVertical  \
# 0                  E-Tech                             E-learning
# 1          Transportation              App based shuttle service
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head()
# Out:
#    Sr No      Date dd/mm/yyyy                  Startup Name  \
# 0      1  2020-01-09 00:00:00                        BYJU’S
# 1      2  2020-01-13 00:00:00                        Shuttl
# 2      3  2020-01-09 00:00:00                     Mamaearth
# 3      4  2020-01-02 00:00:00  https://www.wealthbucket.in/
# 4      5  2020-01-02 00:00:00                        Fashor
#
#      Industry Vertical                            SubVertical City  Location  \
# 0               E-Tech                             E-learning      Bengaluru
# 1       Transportation              App based shuttle service        Gurgaon
# 2           E-commerce  Retailer of baby and toddler products      Bengaluru
# 3              FinTech                      Online Investment      New Delhi
# 4  Fashion and Apparel            Embroiled Clothes For Women         Mumbai
#
#               Investors Name        InvestmentType Amount in USD Remarks
# ...

# %%
df.head(10)
# Out:
#    Sr No      Date dd/mm/yyyy                  Startup Name  \
# 0      1  2020-01-09 00:00:00                        BYJU’S
# 1      2  2020-01-13 00:00:00                        Shuttl
# 2      3  2020-01-09 00:00:00                     Mamaearth
# 3      4  2020-01-02 00:00:00  https://www.wealthbucket.in/
# 4      5  2020-01-02 00:00:00                        Fashor
# 5      6  2020-01-13 00:00:00                         Pando
# 6      7  2020-01-10 00:00:00                        Zomato
# 7      8  2019-12-12 00:00:00                        Ecozen
# 8      9  2019-12-06 00:00:00                      CarDekho
# 9     10  2019-12-03 00:00:00                  Dhruva Space
#
#      Industry Vertical                               SubVertical  \
# 0               E-Tech                                E-learning
# 1       Transportation                 App based shuttle service
# 2           E-commerce     Retailer of baby and toddler products
# ...

# %%
df.tail()
# Out:
#       Sr No      Date dd/mm/yyyy      Startup Name Industry Vertical  \
# 3039   3040  2015-01-29 00:00:00        Printvenue               NaN
# 3040   3041  2015-01-29 00:00:00          Graphene               NaN
# 3041   3042  2015-01-30 00:00:00    Mad Street Den               NaN
# 3042   3043  2015-01-30 00:00:00         Simplotel               NaN
# 3043   3044  2015-01-31 00:00:00  couponmachine.in               NaN
#
#      SubVertical City  Location                     Investors Name  \
# 3039         NaN            NaN        Asia Pacific Internet Group
# 3040         NaN            NaN                     KARSEMVEN Fund
# 3041         NaN            NaN     Exfinity Fund, GrowX Ventures.
# 3042         NaN            NaN                         MakeMyTrip
# 3043         NaN            NaN  UK based Group of Angel Investors
#
#       InvestmentType Amount in USD                            Remarks
# 3039  Private Equity       4500000                                NaN
# ...

# %%
df.tail(7)
# Out:
#       Sr No      Date dd/mm/yyyy      Startup Name Industry Vertical  \
# 3037   3038  2015-01-27 00:00:00      CarDekho.com               NaN
# 3038   3039  2015-01-28 00:00:00     Grabhouse.com               NaN
# 3039   3040  2015-01-29 00:00:00        Printvenue               NaN
# 3040   3041  2015-01-29 00:00:00          Graphene               NaN
# 3041   3042  2015-01-30 00:00:00    Mad Street Den               NaN
# 3042   3043  2015-01-30 00:00:00         Simplotel               NaN
# 3043   3044  2015-01-31 00:00:00  couponmachine.in               NaN
#
#      SubVertical City  Location                       Investors Name  \
# 3037         NaN            NaN  Hillhouse Capital, Tybourne Capital
# 3038         NaN            NaN     Kalaari Capital, Sequoia Capital
# 3039         NaN            NaN          Asia Pacific Internet Group
# 3040         NaN            NaN                       KARSEMVEN Fund
# ...

# %%
df.columns
# Out:
# Index(['Sr No', 'Date dd/mm/yyyy', 'Startup Name', 'Industry Vertical',
#        'SubVertical', 'City  Location', 'Investors Name', 'InvestmentType',
#        'Amount in USD', 'Remarks'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3044 entries, 0 to 3043
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Sr No              3044 non-null   int64
#  1   Date dd/mm/yyyy    3044 non-null   object
#  2   Startup Name       3044 non-null   object
#  3   Industry Vertical  2873 non-null   object
#  4   SubVertical        2108 non-null   object
#  5   City  Location     2864 non-null   object
#  6   Investors Name     3020 non-null   object
#  7   InvestmentType     3040 non-null   object
#  8   Amount in USD      2084 non-null   object
#  9   Remarks            419 non-null    object
# dtypes: int64(1), object(9)
# memory usage: 237.9+ KB

# %%
df.describe()
# Out:
#              Sr No
# count  3044.000000
# mean   1522.500000
# std     878.871435
# min       1.000000
# 25%     761.750000
# 50%    1522.500000
# 75%    2283.250000
# max    3044.000000

# %%
df['Startup Name']
# Out:
# 0                             BYJU’S
# 1                             Shuttl
# 2                          Mamaearth
# 3       https://www.wealthbucket.in/
# 4                             Fashor
#                     ...
# 3039                      Printvenue
# 3040                        Graphene
# 3041                  Mad Street Den
# 3042                       Simplotel
# 3043                couponmachine.in
# Name: Startup Name, Length: 3044, dtype: object

# %%
df['Startup Name'].values
# Out:
# array(['BYJU’S', 'Shuttl', 'Mamaearth', ..., 'Mad Street Den',
#        'Simplotel', 'couponmachine.in'], dtype=object)

# %%
df['Startup Name'].unique()
# Out:
# array(['BYJU’S', 'Shuttl', 'Mamaearth', ..., 'Graphene', 'Simplotel',
#        'couponmachine.in'], dtype=object)

# %%
df=df.head(100)
df['Startup Name'].values
# Out:
# array(['BYJU’S', 'Shuttl', 'Mamaearth', 'https://www.wealthbucket.in/',
#        'Fashor', 'Pando', 'Zomato', 'Ecozen', 'CarDekho', 'Dhruva Space',
#        'Rivigo', 'Healthians', 'Licious', 'InCred', 'Trell', 'Rein Games',
#        'Lenskart.com', 'Freshworks', 'Misters',
#        'Sunstone Eduversity Pvt. Ltd', 'Burger Singh', 'Healthians',
#        'Ninjacart', 'Aye Finance', 'SuperGaming', 'Clumio', 'eBikeGo',
#        'Digital Mall Asia', 'Medikabazaar', 'Vogo Automotive',
#        'Furtados School of Music', 'Paytm', 'Dunzo', 'Udaan',
#        'The Man Company', 'FPL Technologies', 'Cashflo', 'Digital F5',
#        '3rdFlix', '75F', 'Myelin Foundry', 'Atomberg Technology', 'GOQii',
#        'Vyapar App', 'CarDekho', 'Progcap', 'MyPetrolPump',
#        'Alteria Capital', 'Pine Labs', 'Meesho', 'Cars24', 'Uniphore',
#        'Zendrive', 'Lo! Foods', 'Tala', 'INDwealth', 'HungerBox',
#        'AdmitKard', 'Mishry Reviews', 'Grofers', 'Rapido Bike Taxi',
# ...

# %%
df['Startup Name'].unique()
# Out:
# array(['BYJU’S', 'Shuttl', 'Mamaearth', 'https://www.wealthbucket.in/',
#        'Fashor', 'Pando', 'Zomato', 'Ecozen', 'CarDekho', 'Dhruva Space',
#        'Rivigo', 'Healthians', 'Licious', 'InCred', 'Trell', 'Rein Games',
#        'Lenskart.com', 'Freshworks', 'Misters',
#        'Sunstone Eduversity Pvt. Ltd', 'Burger Singh', 'Ninjacart',
#        'Aye Finance', 'SuperGaming', 'Clumio', 'eBikeGo',
#        'Digital Mall Asia', 'Medikabazaar', 'Vogo Automotive',
#        'Furtados School of Music', 'Paytm', 'Dunzo', 'Udaan',
#        'The Man Company', 'FPL Technologies', 'Cashflo', 'Digital F5',
#        '3rdFlix', '75F', 'Myelin Foundry', 'Atomberg Technology', 'GOQii',
#        'Vyapar App', 'Progcap', 'MyPetrolPump', 'Alteria Capital',
#        'Pine Labs', 'Meesho', 'Cars24', 'Uniphore', 'Zendrive',
#        'Lo! Foods', 'Tala', 'INDwealth', 'HungerBox', 'AdmitKard',
#        'Mishry Reviews', 'Grofers', 'Rapido Bike Taxi', 'RenewBuy',
# ...

# %%
df=df.head(100)
df['Startup Name'].value_counts()
# Out:
# Startup Name
# Uniphore                    2
# CarDekho                    2
# Healthians                  2
# Bira91                      2
# BYJU’S                      1
#                            ..
# Dunzo                       1
# Paytm                       1
# Furtados School of Music    1
# Vogo Automotive             1
# Medlife                     1
# Name: count, Length: 96, dtype: int64

# %%
df.loc[0]
# Out:
# Sr No                                      1
# Date dd/mm/yyyy          2020-01-09 00:00:00
# Startup Name                          BYJU’S
# Industry Vertical                     E-Tech
# SubVertical                       E-learning
# City  Location                     Bengaluru
# Investors Name       Tiger Global Management
# InvestmentType          Private Equity Round
# Amount in USD                      200000000
# Remarks                                  NaN
# Name: 0, dtype: object

# %%
df.head()
# Out:
#    Sr No      Date dd/mm/yyyy                  Startup Name  \
# 0      1  2020-01-09 00:00:00                        BYJU’S
# 1      2  2020-01-13 00:00:00                        Shuttl
# 2      3  2020-01-09 00:00:00                     Mamaearth
# 3      4  2020-01-02 00:00:00  https://www.wealthbucket.in/
# 4      5  2020-01-02 00:00:00                        Fashor
#
#      Industry Vertical                            SubVertical City  Location  \
# 0               E-Tech                             E-learning      Bengaluru
# 1       Transportation              App based shuttle service        Gurgaon
# 2           E-commerce  Retailer of baby and toddler products      Bengaluru
# 3              FinTech                      Online Investment      New Delhi
# 4  Fashion and Apparel            Embroiled Clothes For Women         Mumbai
#
#               Investors Name        InvestmentType Amount in USD Remarks
# ...

# %%
df.loc[1]
# Out:
# Sr No                                        2
# Date dd/mm/yyyy            2020-01-13 00:00:00
# Startup Name                            Shuttl
# Industry Vertical               Transportation
# SubVertical          App based shuttle service
# City  Location                         Gurgaon
# Investors Name       Susquehanna Growth Equity
# InvestmentType                        Series C
# Amount in USD                          8048394
# Remarks                                    NaN
# Name: 1, dtype: object

# %%
df.loc[9:14]
# Out:
#     Sr No      Date dd/mm/yyyy  Startup Name             Industry Vertical  \
# 9      10  2019-12-03 00:00:00  Dhruva Space                     Aerospace
# 10     11  2019-12-13 00:00:00        Rivigo                    Technology
# 11     12  2019-12-17 00:00:00    Healthians  B2B-focused foodtech startup
# 12     13  2019-12-16 00:00:00       Licious                    E-Commerce
# 13     14  2019-12-16 00:00:00        InCred                       Finance
# 14     15  2019-12-14 00:00:00         Trell                         Video
#
#                                  SubVertical City  Location  \
# 9                    Satellite Communication      Bengaluru
# 10          Logistics Services and Solutions        Gurgaon
# 11              Food Solutions For Corporate      Bengaluru
# 12  Online Meat And Seafood Ordering Startup      Bengaluru
# 13             Non-Banking Financial Company         Mumbai
# 14             Experience Discovery Platform      Bengaluru
#
# ...

# %%
df.iloc[10:15,2:6]
# Out:
#    Startup Name             Industry Vertical  \
# 10       Rivigo                    Technology
# 11   Healthians  B2B-focused foodtech startup
# 12      Licious                    E-Commerce
# 13       InCred                       Finance
# 14        Trell                         Video
#
#                                  SubVertical City  Location
# 10          Logistics Services and Solutions        Gurgaon
# 11              Food Solutions For Corporate      Bengaluru
# 12  Online Meat And Seafood Ordering Startup      Bengaluru
# 13             Non-Banking Financial Company         Mumbai
# 14             Experience Discovery Platform      Bengaluru

# %%
# get the data from row number 12 to 21 and columns 6 to end
df.iloc[12:22,6:]
# Out:
#                                        Investors Name InvestmentType  \
# 12                                 Vertex Growth Fund       Series E
# 13                                                NaN   Debt Funding
# 14                                Ruizheng Investment     Seed Round
# 15         Manipal Education and Medical Group (MEMG)     Seed Round
# 16                               SoftBank Vision Fund       Series G
# 17                           Sequoia, CapitalG, Accel       Series H
# 18                      Sauce.vc, Rainforest Ventures       Series B
# 19  Prime Venture Partners, LetsVenture, PS1 Ventu...           Seed
# 20                                     RB Investments        Venture
# 21                   DG Daiwa Ventures, DG Incubation       Series B
#
#    Amount in USD Remarks
# 12      30000000     NaN
# 13       5900000     NaN
# 14       2000000     NaN
# 15      50000000     NaN
# 16     231000000     NaN
# 17     150000000     NaN
# ...

# %%
type(df['Amount in USD'])
# Out:
# pandas.core.series.Series

# %%
type(df.loc[0])
# Out:
# pandas.core.series.Series

# %%
df[['Investors Name','InvestmentType']].loc[10:20]
# Out:
#                                        Investors Name InvestmentType
# 10       SAIF Partners, Spring Canter Investment Ltd.       Series F
# 11            Paytm, NPTK, Sabre Partners and Neoplux       Series C
# 12                                 Vertex Growth Fund       Series E
# 13                                                NaN   Debt Funding
# 14                                Ruizheng Investment     Seed Round
# 15         Manipal Education and Medical Group (MEMG)     Seed Round
# 16                               SoftBank Vision Fund       Series G
# 17                           Sequoia, CapitalG, Accel       Series H
# 18                      Sauce.vc, Rainforest Ventures       Series B
# 19  Prime Venture Partners, LetsVenture, PS1 Ventu...           Seed
# 20                                     RB Investments        Venture

# %%
df.to_csv(r"C:/Users/User/Downloads/modified_data1.csv")

# %%
df.to_excel(r'C:/Users/User/Downloads/modified_data.xlsx')

# %%
df[df['InvestmentType']=='Series C']
# Out:
#     Sr No      Date dd/mm/yyyy  Startup Name             Industry Vertical  \
# 1       2  2020-01-13 00:00:00        Shuttl                Transportation
# 11     12  2019-12-17 00:00:00    Healthians  B2B-focused foodtech startup
# 25     26  2019-11-20 00:00:00        Clumio                          SaaS
# 42     43  2019-09-04 00:00:00         GOQii           Health and Wellness
# 44     45  2019-08-01 00:00:00      CarDekho                    E-Commerce
# 51     52  2019-08-13 00:00:00      Uniphore     Customer Service Platform
# 56     57  2019-08-21 00:00:00     HungerBox             Food and Beverage
# 65     66  2019-07-01 00:00:00      Uniphore       Artificial Intelligence
# 74     75  2019-06-05 00:00:00      NoBroker                    E-Commerce
# 93     94  2019-05-02 00:00:00        Zenoti                          Saas
# 94     95  2019-05-28 00:00:00  Ather Energy                    Automobile
#
#                      SubVertical City  Location  \
# ...

# %%
# city Bengaluru
df[df['City  Location']=='Bengaluru']
# Out:
#     Sr No      Date dd/mm/yyyy       Startup Name  \
# 0       1  2020-01-09 00:00:00             BYJU’S
# 2       3  2020-01-09 00:00:00          Mamaearth
# 9      10  2019-12-03 00:00:00       Dhruva Space
# 11     12  2019-12-17 00:00:00         Healthians
# 12     13  2019-12-16 00:00:00            Licious
# 14     15  2019-12-14 00:00:00              Trell
# 22     23  2019-11-15 00:00:00          Ninjacart
# 32     33  2019-10-04 00:00:00              Dunzo
# 33     34  2019-10-02 00:00:00              Udaan
# 40     41  2019-09-04 00:00:00     Myelin Foundry
# 43     44  2019-09-03 00:00:00         Vyapar App
# 46     47  2019-08-01 00:00:00       MyPetrolPump
# 49     50  2019-08-12 00:00:00             Meesho
# 53     54  2019-08-23 00:00:00          Lo! Foods
# 56     57  2019-08-21 00:00:00          HungerBox
# 60     61  2019-08-27 00:00:00   Rapido Bike Taxi
# 67     68  2019-07-10 00:00:00         "BYJU\\'S"
# 74     75  2019-06-05 00:00:00           NoBroker
# ...

# %%
df.isna().sum()
# Out:
# Sr No                  0
# Date dd/mm/yyyy        0
# Startup Name           0
# Industry Vertical      0
# SubVertical            0
# City  Location         0
# Investors Name         2
# InvestmentType         3
# Amount in USD          0
# Remarks              100
# dtype: int64
