# %%
# !pip install seaborn
# Out:
# ...
# [notice] A new release of pip is available: 23.3.1 -> 23.3.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
weight =[63,70,78,86]
height=[5.2,5.4,5.8,6.2]
plt.plot(weight,height)
plt.show()

# %%
weight =[63,70,78,86]
height=[5.2,5.4,5.8,6.2]
plt.plot(weight,height,marker="*")
plt.show()

# %%
weight =[63,70,78,86]
height=[5.2,5.4,5.8,6.2]
plt.plot(weight,height,marker="p")
plt.show()

# %%
weight =[63,70,78,86]
height=[5.2,5.4,5.8,6.2]
plt.plot(weight,height,marker="d")
plt.show()

# %%
weight =[63,70,78,86]
height=[5.2,5.4,5.8,6.2]
plt.plot(weight,height,marker="d",color="red")
plt.show()

# %%
weight =[63,70,78,86]
height=[5.2,5.4,5.8,6.2]
plt.plot(weight,height,marker="d",color="red",mec="black")
plt.show()

# %%
weight =[63,70,78,86]
height=[5.2,5.4,5.8,6.2]
plt.plot(weight,height,marker="d",color="red",mec="black",mfc="pink")
plt.show()
#marker edge color 
#marker face color

# %%
weight =[63,70,78,86]
height=[5.2,5.4,5.8,6.2]
plt.scatter(weight,height,color='#9e32a8')
plt.show()

# %%
weight =[63,70,78,86]
height=[5.2,5.4,5.8,6.2]
plt.scatter(weight,height,color='#f0f022')
plt.show()

# %%
weight =[63,70,78,86]
height=[5.2,5.4,5.8,6.2]
plt.scatter(weight,height,color='#f0f022')
font_dict={'size':16,'color':'#db1ac8'}
plt.xlabel("weight",font_dict)
plt.ylabel("Height",font_dict)
plt.title("Height vs Weight",font_dict)
plt.grid()
plt.show()

# %%
course=['DS','DE','AIML','FSD']
students=[100,110,120,130]
plt.bar(course,students,color=['#DC84F3','#4942E4','#5F8670','#5F0F40'])
font_dict={'size':14,'color':'black'}
plt.xlabel('Course Name',font_dict)
plt.ylabel('Enrollments',font_dict)
plt.title("",font_dict)
plt.show()

# %%
#course=['DS','DE','AIML','FSD']
import numpy as  np
course=np.arange(4)
students=[100,110,120,130]
plt.bar(course-0.2,students,width=0.4,color=['#C5FFF8','#96EFFF','#5FBDFF','#7B66FF'])

#course=['DS','DE','AIML','FSD']
students=[30,150,190,70]
plt.bar(course+0.2,students,width=0.4,color=['#FED9ED','#E7BCDE','#BB9CC0','#67729D'])

plt.xticks(course,['DS','DE','AIML','FSD'])
font_dict={'size':14,'color':'black'}
plt.xlabel('Course Name',font_dict)
plt.ylabel('Enrollments',font_dict)
plt.title("",font_dict)
plt.show()

# %%
#course=['DS','DE','AIML','FSD']
plt.style.use('classic')
import numpy as  np
course=np.arange(4)
male=[100,110,120,130]
plt.bar(course,male,color=['#C5FFF8','#96EFFF','#5FBDFF','#7B66FF'])

#course=['DS','DE','AIML','FSD']
female=[30,150,190,70]
plt.bar(course,female,bottom=male,color=['#FED9ED','#E7BCDE','#BB9CC0','#67729D'])

plt.xticks(course,['DS','DE','AIML','FSD'])
font_dict={'size':14,'color':'black'}
plt.xlabel('Course Name',font_dict)
plt.ylabel('Enrollments',font_dict)
plt.title("",font_dict)
plt.show()

# %%
#course=['DS','DE','AIML','FSD']
plt.style.use('Solarize_Light2')
import numpy as  np
course=np.arange(4)
male=[100,110,120,130]
plt.bar(course,male,color=['#C5FFF8','#96EFFF','#5FBDFF','#7B66FF'])

#course=['DS','DE','AIML','FSD']
female=[30,150,190,70]
plt.bar(course,female,bottom=male,color=['#FED9ED','#E7BCDE','#BB9CC0','#67729D'])

plt.xticks(course,['DS','DE','AIML','FSD'])
font_dict={'size':14,'color':'black'}
plt.xlabel('Course Name',font_dict)
plt.ylabel('Enrollments',font_dict)
plt.title("",font_dict)
plt.show()

# %%
#course=['DS','DE','AIML','FSD']
plt.style.use('dark_background')
import numpy as  np
course=np.arange(4)
male=[100,110,120,130]
plt.bar(course,male,color=['#C5FFF8','#96EFFF','#5FBDFF','#7B66FF'])

#course=['DS','DE','AIML','FSD']
female=[30,150,190,70]
plt.bar(course,female,bottom=male,color=['#FED9ED','#E7BCDE','#BB9CC0','#67729D'])

plt.xticks(course,['DS','DE','AIML','FSD'])
font_dict={'size':14,'color':'black'}
plt.xlabel('Course Name',font_dict)
plt.ylabel('Enrollments',font_dict)
plt.title("",font_dict)
plt.show()

# %%
#course=['DS','DE','AIML','FSD']
plt.style.use('grayscale')
import numpy as  np
course=np.arange(4)
male=[100,110,120,130]
plt.bar(course,male,color=['#C5FFF8','#96EFFF','#5FBDFF','#7B66FF'])

#course=['DS','DE','AIML','FSD']
female=[30,150,190,70]
plt.bar(course,female,bottom=male,color=['#FED9ED','#E7BCDE','#BB9CC0','#67729D'])

plt.xticks(course,['DS','DE','AIML','FSD'])
font_dict={'size':14,'color':'black'}
plt.xlabel('Course Name',font_dict)
plt.ylabel('Enrollments',font_dict)
plt.title("",font_dict)
plt.show()

# %%
#course=['DS','DE','AIML','FSD']
plt.style.use('fast')
import numpy as  np
course=np.arange(4)
male=[100,110,120,130]
plt.bar(course,male,color=['#C5FFF8','#96EFFF','#5FBDFF','#7B66FF'])

#course=['DS','DE','AIML','FSD']
female=[30,150,190,70]
plt.bar(course,female,bottom=male,color=['#FED9ED','#E7BCDE','#BB9CC0','#67729D'])

plt.xticks(course,['DS','DE','AIML','FSD'])
font_dict={'size':14,'color':'black'}
plt.xlabel('Course Name',font_dict)
plt.ylabel('Enrollments',font_dict)
plt.title("",font_dict)
plt.show()

# %%
#course=['DS','DE','AIML','FSD']
plt.style.use('fivethirtyeight')
import numpy as  np
course=np.arange(4)
male=[100,110,120,130]
plt.bar(course,male,color=['#C5FFF8','#96EFFF','#5FBDFF','#7B66FF'])

#course=['DS','DE','AIML','FSD']
female=[30,150,190,70]
plt.bar(course,female,bottom=male,color=['#FED9ED','#E7BCDE','#BB9CC0','#67729D'])

plt.xticks(course,['DS','DE','AIML','FSD'])
font_dict={'size':14,'color':'black'}
plt.xlabel('Course Name',font_dict)
plt.ylabel('Enrollments',font_dict)
plt.title("",font_dict)
plt.show()

# %%
course=['DS','DE','AIML','FSD']
students=[100,110,120,130]
plt.pie(students,labels=course,explode=[0.1,0,0,0],shadow=True,colors=['#DC84F3','#4942E4','#5F8670','#5F0F40'])
plt.show()

# %%
course=['DS','DE','AIML','FSD']
students=[100,110,120,130]
plt.subplot(2,2,1)
plt.pie(students,labels=course,explode=[0.1,0,0,0],colors=['#DC84F3','#4942E4','#5F8670','#5F0F40'])

plt.subplot(2,2,2)
course=['DS','DE','AIML','FSD']
students=[100,110,120,130]
plt.bar(course,students,color=['#DC84F3','#4942E4','#5F8670','#5F0F40'])

plt.subplot(2,2,3)
weight =[63,70,78,86]
height=[5.2,5.4,5.8,6.2]
plt.scatter(weight,height,color='#f0f022')

plt.subplot(2,2,4)
weight =[63,70,78,86]
height=[5.2,5.4,5.8,6.2]
plt.plot(weight,height,color='#9e32a8')
plt.show()


plt.show()

# %%
marks=[0,1,6,7,5,7,8,9,6,5,7,4,5,6,7,8,9,10,1,3,6,5,4,7,8,8,8,9,9,5,9,6,7,8,4,5,6,4,5,6,7,4,9]
plt.hist(marks,bins=5)
plt.show()

# %%
#course=['DS','DE','AIML','FSD']
plt.style.use('classic')
import numpy as  np
course=0.2+np.arange(4)
male=[100,110,120,130]
plt.stem(course,male)
plt.show()

# %%
#course=['DS','DE','AIML','FSD']
plt.style.use('classic')
course=0.2+np.arange(10)
male=[100,110,120,130,37,58,90,78,67,89]
plt.stairs(male,linewidth=3)
plt.show()

# %%
course=0.2+np.arange(10)
male=[100,110,120,130,37,58,90,78,67,89]
err=[4,6,2,1,8,6,7,4,9,2]
plt.errorbar(course,male,err,fmt="o",linewidth=2,capsize=4)
plt.show()

# %% [markdown]
# # 30 Dec 2023

# %%
# !pip install seaborn
# Out:
# ...
# [notice] A new release of pip is available: 23.3.1 -> 23.3.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=sns.load_dataset('iris')
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df=sns.load_dataset('tips')
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.scatterplot(data=df,x='total_bill',y='tip',hue='sex')
plt.show()

# %%
sns.set_palette("Set2")
sns.scatterplot(data=df,x='total_bill',y='tip',hue='sex',style='day',size='size')
plt.show()

# %%
df=sns.load_dataset('flights')
df
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
sns.lineplot(data=df,x='year',y='passengers')
plt.show()

# %%
sns.lineplot(data=df,x='year',y='passengers',style="month")
plt.show()

# %%
sns.lineplot(data=df,x='year',y='passengers',style="month",hue="month")
plt.show()

# %%
df=sns.load_dataset('tips')
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.barplot(data=df,x='day',y='tip',color='yellow')
plt.show()

# %%
sns.barplot(data=df,x='day',y='tip',hue="time")
plt.show()

# %%
sns.barplot(data=df,x='day',y='tip',hue="sex")
plt.show()

# %%
df.plot(kind="bar")
# Out:
# <Axes: >

# %%
df.index=df['day']
df[['tip','day']].plot.bar(x='day')
# Out:
# <Axes: xlabel='day'>

# %%
df
# Out:
#       total_bill   tip     sex smoker   day    time  size
# day
# Sun        16.99  1.01  Female     No   Sun  Dinner     2
# Sun        10.34  1.66    Male     No   Sun  Dinner     3
# Sun        21.01  3.50    Male     No   Sun  Dinner     3
# Sun        23.68  3.31    Male     No   Sun  Dinner     2
# Sun        24.59  3.61  Female     No   Sun  Dinner     4
# ...          ...   ...     ...    ...   ...     ...   ...
# Sat        29.03  5.92    Male     No   Sat  Dinner     3
# Sat        27.18  2.00  Female    Yes   Sat  Dinner     2
# Sat        22.67  2.00    Male    Yes   Sat  Dinner     2
# Sat        17.82  1.75    Male     No   Sat  Dinner     2
# Thur       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df=sns.load_dataset('tips')
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.boxplot(data=df,x='day',y='total_bill')
plt.show()

# %%
df=sns.load_dataset('tips')
sns.pairplot(df)
plt.show()
